# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
from requests_testadapter import Resp
import requests
#from requests_file import FileAdapter
import os.path

# %%
#limpiamos el DF en memoria para iniciar el proceso.
df = pd.DataFrame()
df_reviews = pd.DataFrame()

#ruta de donde vamos a tomar los htmls.
ruta = "C:/Users/Joaquin/Documents/GitHub/desafio-final/Data/Prueba/c/"

#recorremos todos los archivos en la ruta. 
for filename in os.listdir(ruta):
        file =  open(ruta+filename, "r", encoding='utf-8') #abrimos el archivo

        bsObj = BeautifulSoup(file, 'html.parser') #generamos el objeto beautiful soup
        #bsObj.encode('utf-8')
        #print(bsObj.original_encoding)
    

#TOMA DE CONTENIDO - ETIQUETAS HTML
                       
        aclass = bsObj.findAll("a", {"class":"display-extended-links"}) #obtenemos barrio y tipo comida de esta var
        
        tipo_comida_pre = bsObj.findAll("a", {"class":"display-extended-links"}) 
        tipo_comida = []                      
        if len(tipo_comida_pre) - 2 >= 0:
            for i in range( 0, len(tipo_comida_pre) - 2 ):
                tipo_comida.append(tipo_comida_pre[i].get_text())     
        
        
        actividades_pre = bsObj.findAll("h4",{"class":"tile-text-sm description"})
        actividades= []
        for i in range( 0, len(actividades_pre)):
            actividades.append(actividades_pre[i].get_text())
        
        
        extras_pre = bsObj.findAll("h4",{"class":"title-text-sm description"})
        extras = []
        for i in range( 0, len(extras_pre)):
            extras.append(extras_pre[i].get_text())
        
        barrio = []
        if len(aclass) -2 >= 0 :
            barrio = bsObj.findAll("a", {"class":"display-extended-links"})[len(aclass)-2].text 

        nombre_lugar = filename[0:len(filename)-5] 

        
        price_range = []
        #price_range = bsObj.find("span", {"class":"price-range"}) - version vieja borrar
        price_range_b = bsObj.find("span", {"class":"price-range"})
        if price_range_b != None:
            price_range = price_range_b['class'][1].replace("price-range-","")
 
    
        reviews = bsObj.findAll("p",{"class":"activity-text"})
        reviews_date = bsObj.findAll("div",{"class":"activity-date"})
        print(reviews)
        
        #en proceso
        puntaje_review = []      
        puntaje_review = bsObj.findAll("div",{"class":"activity-ratings"})
#        puntaje_review_b = puntaje_review[0].findAll("span")
#         review_comida_b = puntaje_review_b[2].get_text().strip()
#         review_servicio_b = puntaje_review_b[5].text
#         review_ambiente_b = puntaje_review_b[8].text
#         review_comida = " ".join(review_comida_b.split())
#         review_servicio = " ".joinreview_servicio_b.split())
#         review_ambiente = " ".join(review_ambiente_b.split())
        
        
        
        #GUARDADO DE DATOS CON APPEND MEDIANTE ITERACIONES
        
        serie = pd.Series([nombre_lugar, tipo_comida, barrio, price_range, actividades, extras], index=['nombre_lugar', 'tipo_comida', 'barrio', 'price_range', 'actividades', 'extras'])
        df = df.append(serie, ignore_index=True)
        
        serie_reviews = pd.Series([nombre_lugar, reviews, reviews_date, puntaje_review]) #index=['nombre_lugar', 'reviews'])
        df_reviews = df_reviews.append(serie_reviews, ignore_index=True)

        

export_csv = df.to_csv ('df_scrapping_sept.csv', index = None, header=True)
# Out:
ero la comida PESIMA , de muy mala calidad, tienen 3 menues que arrancan en los $ 180, $ 270 y $  360 sino la carta, donde ning\xc3\xban plato baja de $ 150, pedimos el menu de  180, ropa vieja, donde la carne zafaba pero el arroz era recalentado y gomoso, y un menu donde la pata de pollo ten\xc3\xada un color y sabor desagradable. Los tragos a partir de $ 50. Fuimos por el show que no sabemos si es porque hab\xc3\xada poco gente, ten\xc3\xada menos de cubano que otra cosa. La verdad NO FUE UNA BUENA experiencia y NO LO RECOMDAMOS, por ese dinero se puede ir a mejores lugares. Servicio de mesa $15.</p>, <p class="activity-text">La comida es buena, nada excepcional. El mozo bastante malhumorado. Lo que hizo la noche fue el show, jam\xc3\xa1s vi tanta gente cop\xc3\xa1ndose para bailar salsa, el grupo le pone. No tienen envases para llevar y despu\xc3\xa9s de insistir (demasiado) nos trajeron uno. Sin groupon no volver\xc3\xada</p>, <p class="activity-text">Fuimos 4 personas con un cupon de descuento, lo pasamos muy bien. Muy lindo ambiente,  con muy buena onda</p>]
# []
# []
# [<p class="activity-text">excelente</p>]
# []
# [<p class="activity-text">Atenci\xc3\xb3n desastrosa. Vayan con paciencia...</p>, <p class="activity-text">Sucursal Mart\xc3\xadnez pedimos un t\xc3\xa9 y un caf\xc3\xa9 local semi vac\xc3\xado 15 minutos para que nos traigan las cosas</p>, <p class="activity-text">muy rico el brunch de salm\xc3\xb3n , trae de todo, el precio es un poco elevado , buena atenci\xc3\xb2n, lugar agradable .</p>, <p class="activity-text">me encanta las opciones light de este lugar! lo mejor la hamburguesa de portobellos! Capaz un poco caro, pero vale la pena cada tanto</p>, <p class="activity-text">Un desastre desde el vamos. Hab\xc3\xadamos reservado mesa, cuando llegamos estaba ocupada. No ten\xc3\xadan coca light, la cerveza estaba caliente y la comida tardo m\xc3\xa1s de dos horas. Carisimo para lo que es.</p>, <p class="activity-text">Muy rico el bud\xc3\xadn de amapolas y lim\xc3\xb3n! Recomiendo para merendar , ambiente agradable.</p>, <p class="activity-text">Mucha variedad de t\xc3\xa9s, rica pasteler\xc3\xada, buena atenci\xc3\xb3n, muy lindo jard\xc3\xadn de invierno. Ir con paciencia, hay que esperar. Siempre vamos a tomar un rico t\xc3\xa9.</p>, <p class="activity-text">Buen ambiente los platos simples y ricos </p>, <p class="activity-text">Todo muy rico. La camamera muy amable, sin embargo tengo una critica importante para hacer: no nos permitieron usar el jardin. Me informaron que dentro de una hora se podria usar. Respondi que habia gente afuera, y me dijeron que esa gente estaba de antes. Aclaro que habia disponibilidad de mesas. Cuando vuelvo a preguntar por que no se podia usar el jardin, me dijeron que hasta que no llegara el personal del siguiente turno el jardin no se podia usar... Lamentable que una boutique de t\xc3\xa9, que esta dirigida a un p\xc3\xbablico exigente, tenga como pol\xc3\xadtica clausurar el jardin porque no llego el personal del turno siguiente...</p>, <p class="activity-text">A mi particularmente Tea Connection siempre me gust\xc3\xb3, y esta sede es de las m\xc3\xa1s lindas en cuanto ambiente. Lo que me sorprendi\xc3\xb3 esta \xc3\xbaltima vez que fui, fue que achicaron los platos y est\xc3\xa1 bastante m\xc3\xa1s caro.</p>]
a1culos de calamar. varios pedimos el mismo plato porque parec\xc3\xada apetitoso, y a todos nos sirvieron igual. el arroz tambi\xc3\xa9n estaba soso, lo que tratamos de solucionar agreg\xc3\xa1ndole la pasta de zanahorias que nos hab\xc3\xadan dado de entrada, pero solo lo hizo tragable. el panqueque solo era comestible en los sectores que tenia las rodajas de manzana. muy caro para esa calidad. no volveremos</p>]

# %%
#tomamos df_reviews generado en el paso anterior e iteramos por la lista de reviews y sus fechas y las guardamos como registros
#independientes en un nuevo dataframe.

df_reviews_shaped = pd.DataFrame()
resto_counter = 0
for resto in df_reviews[0].values:
    counter2 = 0
    for item in df_reviews.iloc[resto_counter][1]:
        review = df_reviews.iloc[resto_counter][1][counter2].text
        
        fecha = df_reviews.iloc[resto_counter][2][counter2].text
        
        #iteramos dentro de puntaje y la descomponemos en columna comida, servicio y ambiente.
        #agregamos puntaje al DF reviews, por si queremos controlar la info, despues lo dropeamos.
        try:
            puntaje = df_reviews.iloc[resto_counter][3][counter2]
            puntaje = puntaje.findAll("span")

            comida = puntaje[2].get_text()
            comida = comida.replace('\\t','').replace('\\n','').strip()

            servicio = puntaje[5].get_text()
            servicio = servicio.replace('\\t','').replace('\\n','').strip()

            ambiente = puntaje[8].get_text()
            ambiente = ambiente.replace('\\t','').replace('\\n','').strip()
            
        except IndexError:
             puntaje = None
             comida = None
             servicio = None
             ambiente = None
        
        
        
        serie_reviews_2 = pd.Series([resto, review, fecha, puntaje, comida, servicio, ambiente], index=['resto', 'review', 'fecha', 'puntaje', 'comida', 'servicio', 'ambiente'])
        df_reviews_shaped = df_reviews_shaped.append(serie_reviews_2, ignore_index=True)
        counter2=counter2 + 1
    resto_counter = resto_counter + 1
    
df_reviews_shaped = df_reviews_shaped[['resto','fecha','review','comida', 'servicio', 'ambiente']]
        
#export_csv = df_reviews.to_csv (r'C:/Users/QQ-Haum/Documents/desafio-final/df_reviewss.csv', index = None, header=True) 
#export_csv = df_reviewss.to_csv (r'C:/Users/QQ-Haum/Documents/desafio-final/df_reviewss.csv', index = None, header=True) 
export_csv = df_reviews_shaped.to_csv ('df_scrapping_sept_reviews.csv', index = None, header=True, encoding='utf-8')

# %%
df_reviews_shaped
# Out:
#                                   resto       fecha  \
# 0                           ottilia-477  30/11/2014
# 1   Oye-chico--Complejo-la-Plaza--10116  19/07/2019
# 2   Oye-chico--Complejo-la-Plaza--10116  14/02/2017
# 3   Oye-chico--Complejo-la-Plaza--10116  05/10/2016
# 4   Oye-chico--Complejo-la-Plaza--10116  17/07/2016
# 5   Oye-chico--Complejo-la-Plaza--10116  29/10/2014
# 6   Oye-chico--Complejo-la-Plaza--10116  15/09/2014
# 7   Oye-chico--Complejo-la-Plaza--10116  24/07/2014
# 8   Oye-chico--Complejo-la-Plaza--10116  20/06/2013
# 9   Oye-chico--Complejo-la-Plaza--10116  26/03/2013
# 10  Oye-chico--Complejo-la-Plaza--10116  11/03/2013
# 11                         pamplona-170  03/08/2014
# 12                 Tea-Connection-10226  15/06/2019
# 13                 Tea-Connection-10226  10/11/2017
# 14                 Tea-Connection-10226  30/03/2017
# 15                 Tea-Connection-10226  17/01/2017
# 16                 Tea-Connection-10226  21/12/2016
# 17                 Tea-Connection-10226  02/11/2016
# 18                 Tea-Connection-10226  06/10/2016
# 19                 Tea-Connection-10226  12/02/2016
# 20                 Tea-Connection-10226  27/01/2016
# 21                 Tea-Connection-10226  20/01/2016
# 22                      Territorio-1040  23/06/2013
# 23                      Territorio-1040  15/03/2013
# 24                      Territorio-1040  12/01/2013
# 25                      Territorio-1040  11/12/2012
# 26                      Territorio-1040  16/11/2012
# 27                      Territorio-1040  16/11/2012
# 28                      Territorio-1040  27/05/2012
# 29                      Territorio-1040  25/05/2012
# 30                      Territorio-1040  06/05/2012
# 31                      Territorio-1040  06/01/2012
# 32                         Thaisu-10144  13/05/2016
# 33                         Thaisu-10144  26/02/2016
# 34                         Thaisu-10144  19/02/2014
# 35                         Thaisu-10144  27/01/2014
# 36                         Thaisu-10144  24/07/2013
# 37                         Thaisu-10144  18/10/2012
# 38                         Thaisu-10144  17/10/2012
# 39                         Thaisu-10144  09/10/2012
# 40                         Thaisu-10144  30/07/2012
# 41                         Thaisu-10144  19/06/2012
# 42              Tiempos-organicos-10504  12/08/2012
# 43              Tiempos-organicos-10504  29/04/2012
# 44              Tiempos-organicos-10504  21/12/2011
#
#                                                review     comida   servicio  \
# 0   Concurrimos un mediod\xc3\xada, y a pesar de s...  Excelente  Excelente
# 1   Fuimos con groupon. Comida insipida. Servicio ...    Regular    Regular
# 2   Desped\xc3\xadamos a nuestro Gerente Coordinad...    Regular    Regular
# 3   Me encanto el ambiente volveria a festejar mi ...  Excelente    Regular
# 4   El show y tragos muy bueno!!!! Pero el men\xc3...  Muy bueno  Muy bueno
# 5                Los shows y los tragos son lo mejor!      Bueno  Muy bueno
# 6   Sinceramente es un lugar al cual no volveremos...    Regular    Regular
# 7   A vos que lees esto y consideras conocer Oye c...    Regular      Bueno
# 8   La atenci\xc3\xb3n muy buena pero la comida PE...    Regular      Bueno
# 9   La comida es buena, nada excepcional. El mozo ...      Bueno  Muy bueno
# 10  Fuimos 4 personas con un cupon de descuento, l...  Muy bueno  Muy bueno
# 11                                          excelente  Excelente  Excelente
# 12  Atenci\xc3\xb3n desastrosa. Vayan con pacienci...      Bueno    Regular
# 13  Sucursal Mart\xc3\xadnez pedimos un t\xc3\xa9 ...      Bueno    Regular
# 14  muy rico el brunch de salm\xc3\xb3n , trae de ...      Bueno      Bueno
# 15  me encanta las opciones light de este lugar! l...  Muy bueno    Regular
# 16  Un desastre desde el vamos. Hab\xc3\xadamos re...      Bueno    Regular
# 17  Muy rico el bud\xc3\xadn de amapolas y lim\xc3...  Muy bueno      Bueno
# 18  Mucha variedad de t\xc3\xa9s, rica pasteler\xc...  Muy bueno  Muy bueno
# 19          Buen ambiente los platos simples y ricos   Excelente  Excelente
# 20  Todo muy rico. La camamera muy amable, sin emb...  Excelente  Excelente
# 21  A mi particularmente Tea Connection siempre me...  Muy bueno  Excelente
# 22  Excelente el s\xc3\xa1ndwich vegetariano, y el...  Excelente  Muy bueno
# 23  Muy buen lugar, lindo, buen ambiente, agradabl...  Muy bueno  Muy bueno
# 24  Restaurante de delicatessen Patag\xc3\xb3nico....  Excelente  Excelente
# 25  Los s\xc3\xa1ndwiches son recomendables, porci...  Muy bueno      Bueno
# 26  Ambiente con la onda de San Telmo, bohemio , p...      Bueno      Bueno
# 27  Ambiente con la onda de San Telmo, bohemio , p...      Bueno      Bueno
# 28  Lugar un poco escondido, un poco vac\xc3\xado ...  Muy bueno      Bueno
# 29  fuimos  25 de Mayo a comer locro. Estuvo excel...  Excelente  Muy bueno
# 30  Llegamos de casualidad porque otro lugar estab...  Muy bueno      Bueno
# 31  La picada si bien abundante, no ten\xc3\xada i...      Bueno    Regular
# 32  Hoy fui por primera vez y ped\xc3\xad un men\x...  Excelente  Excelente
# 33  En este lugar son unos negreros, la comida pue...    Regular    Regular
# 34  Vamos todos los mi\xc3\xa9rcoles, ya es un cl\...  Muy bueno  Muy bueno
# 35  El lugar es peque\xc3\xb1o, siempre compr\xc3\...      Bueno    Regular
# 36  Me parece que si lo comparamos con ofertas sim...  Muy bueno      Bueno
# 37  Me pareci\xc3\xb3 demasiado caro para la propu...    Regular    Regular
# 38  Llegu\xc3\xa9 a ser un fan\xc3\xa1tico de este...      Bueno      Bueno
# 39  Vamos seguido con la gente del trabajo. La ate...  Muy bueno      Bueno
# 40  Curry rojo de cerdo : me decepciono , mas gras...    Regular      Bueno
# 41  Muy buena comida y precios mas que razonables ...  Excelente  Excelente
# 42  Es una diferente e interesante conecci\xc3\xb3...  Muy bueno      Bueno
# 43   La casa es preciosa, un ph muy bien puesto co...  Excelente  Excelente
# 44  La comida no esta mal elaborada pero es sosa, ...    Regular      Bueno
#
#      ambiente
# 0   Excelente
# 1     Regular
# 2     Regular
# 3     Regular
# 4   Muy bueno
# 5       Bueno
# 6     Regular
# 7     Regular
# 8   Muy bueno
# 9     Regular
# 10  Excelente
# 11  Excelente
# 12      Bueno
# 13  Muy bueno
# 14      Bueno
# 15      Bueno
# 16    Regular
# 17  Muy bueno
# 18  Muy bueno
# 19  Muy bueno
# 20    Regular
# 21      Bueno
# 22  Excelente
# 23  Muy bueno
# 24  Excelente
# 25  Excelente
# 26      Bueno
# 27      Bueno
# 28      Bueno
# 29  Excelente
# 30      Bueno
# 31      Bueno
# 32  Excelente
# 33    Regular
# 34  Muy bueno
# 35      Bueno
# 36      Bueno
# 37  Excelente
# 38      Bueno
# 39  Muy bueno
# 40      Bueno
# 41  Excelente
# 42  Muy bueno
# 43  Excelente
# 44    Regular
